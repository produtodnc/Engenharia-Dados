# %% [markdown]
# Uma loja de carro esportivo um portfolio de carros importados. E para melhor direcionar suas campanhas de venda e marketing eles precisam categorizar os carros pelo pais de cada montadora, dessa forma ela pode clusterizar seus carros pelo seu pais de origem.
#
# - Carros fabricados em 2020 para frente
# - Carros acima de USD 100,000.00

# %% [markdown]
# ### Extract: Bucket S3
#
# ### Transformation: Aplicar Regras de Negocio
#
# ### Loading: Postgres Database

# %%
import boto3

s3 = boto3.client('s3')
response = s3.list_buckets()

# Output the bucket names
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   aws-glue-assets-764386922584-us-east-1
#   bucket-testing-dnc-lucas-2024
#   dnc-class-datasource-s3
#   dnc-lucas-tutorial-class

# %%
# Listar as pastas de um bucket

# Listing folder from a bucket

bucket_name = 'dnc-lucas-tutorial-class'

prefix = ''
delimiter = '/'

response = s3.list_objects_v2(
    Bucket=bucket_name,
    Prefix=prefix,
    Delimiter=delimiter
)

folders = [prefix['Prefix'] for prefix in response.get('CommonPrefixes', [])]

folders
# Out:
# ['Unsaved/',
#  'cars/',
#  'customers/',
#  'ecommerce/',
#  'loading/',
#  'raw/',
#  'redshift/',
#  'uploading-from-api/',
#  'uploading/',
#  'worldcup/']

# %%
# Dentro da pasta raw, vamos ver quais objetos estao disponiveis

import boto3

# Initialize the S3 client
s3 = boto3.client('s3')

# Bucket name
bucket_name = 'dnc-lucas-tutorial-class'

# List all objects in the bucket
response = s3.list_objects_v2(
    Bucket=bucket_name,
    Prefix="raw/"
)

# Extract the list of objects
objects = response.get('Contents', [])

# Print the list of object keys (file names)
for obj in objects:
    print(obj['Key'])
# Out:
# raw/
# raw/WorldCups.csv
# raw/cars/
# raw/cars/Sport car price.csv
# raw/cars/car-companies-by-country-2024.csv
# raw/ecommerce/olist_customers_dataset.csv
# raw/ecommerce/olist_geolocation_dataset.csv
# raw/ecommerce/olist_order_items_dataset.csv
# raw/ecommerce/olist_order_payments_dataset.csv
# raw/ecommerce/olist_order_reviews_dataset.csv
# raw/ecommerce/olist_orders_dataset.csv
# raw/ecommerce/olist_products_dataset.csv
# raw/ecommerce/olist_sellers_dataset.csv
# raw/ecommerce/product_category_name_translation.csv

# %%
import pandas as pd
from io import StringIO

# Bucket name
bucket_name = 'dnc-lucas-tutorial-class'
file_key = "raw/cars/Sport car price.csv"

response = s3.get_object(Bucket=bucket_name, Key=file_key)
csv_content = response['Body'].read().decode('utf-8')

df_portfolio = pd.read_csv(StringIO(csv_content))

df_portfolio.sample(10)
# Out:
#           Car Make         Car Model  Year Engine Size (L) Horsepower  \
# 899        Porsche            Cayman  2022               2        300
# 69     Lamborghini         Aventador  2021             6.5        770
# 820         Jaguar            F-Type  2022               2        296
# 654         Nissan        370Z Nismo  2021             3.7        350
# 549            BMW             M2 CS  2022               3        444
# 40            Audi               RS3  2022             2.5        394
# 977  Mercedes-Benz            AMG GT  2021               4        523
# 212        Porsche  Panamera Turbo S  2021               4        620
# 723  Mercedes-Benz           SLS AMG  2021               4        730
# 173            TVR          Griffith  2022               5        500
#
#     Torque (lb-ft) 0-60 MPH Time (seconds) Price (in USD)
# 899            280                     4.5         59,900
# 69             531                     2.9        417,826
# 820            295                     5.4         62,500
# 654            276                     4.8         45,000
# 549            406                     3.8         84,595
# 40             369                     3.9         57,000
# 977            494                     3.8        118,500
# 212            604                     2.9        177,700
# 723            590                     2.9        250,000
# 173            479                     3.8        123,500

# %%
df_portfolio["Year"].value_counts()
# Out:
# Year
# 2021    576
# 2022    382
# 2020     25
# 2015     12
# 2019      3
# 2017      3
# 2023      3
# 2014      2
# 1965      1
# Name: count, dtype: int64

# %%
df_portfolio["Price (in USD)"].value_counts().sort_values()
# Out:
# Price (in USD)
# 3,900,000     1
# 49,000        1
# 222,500       1
# 67,800        1
# 78,450        1
#              ..
# 114,000      16
# 58,900       17
# 625,000      22
# 3,000,000    24
# 500,000      34
# Name: count, Length: 367, dtype: int64

# %%
df_portfolio["Car Make"].value_counts()
# Out:
# Car Make
# Porsche          88
# McLaren          75
# Audi             71
# Lamborghini      66
# BMW              63
# Chevrolet        60
# Ferrari          55
# Mercedes-Benz    54
# Aston Martin     50
# Ford             48
# Dodge            41
# Nissan           37
# Lotus            35
# Jaguar           30
# Lexus            26
# Maserati         25
# Bentley          25
# Bugatti          23
# Tesla            19
# Alfa Romeo       16
# Acura            16
# Koenigsegg       15
# Rimac            14
# Pagani           12
# Mercedes-AMG     11
# Rolls-Royce      10
# Toyota            5
# W Motors          3
# Subaru            3
# Pininfarina       2
# TVR               2
# Kia               1
# Alpine            1
# Ariel             1
# Shelby            1
# Mazda             1
# Polestar          1
# Ultima            1
# Name: count, dtype: int64

# %%
import pandas as pd
from io import StringIO

# Bucket name
bucket_name = 'dnc-lucas-tutorial-class'
file_key = "raw/cars/car-companies-by-country-2024.csv"

response = s3.get_object(Bucket=bucket_name, Key=file_key)
csv_content = response['Body'].read().decode('utf-8')

df_country = pd.read_csv(StringIO(csv_content))

df_country.sample(10)
# Out:
#           country  CarCompaniesNumOfCarCompanies  \
# 55  Liechtenstein                              1
# 17          Italy                             61
# 54        Andorra                              1
# 56         Monaco                              1
# 21         Poland                              8
# 3        Pakistan                              1
# 12        Germany                            114
# 31    Netherlands                              9
# 8           Japan                             23
# 1           China                            124
#
#                         CarCompaniesMostPopularBrands
# 55                                       NanoFlowcell
# 17  Abarth, Alfa Romeo, Aprilia, Ferrari, Fiat, La...
# 54                                      TransAm Depot
# 56                                        Monte Carlo
# 21                                   Leopard, Stoewer
# 3                                                Adam
# 12  Audi, BMW, Mercedes-Benz, Opel, Porsche, Smart...
# 31                                          Lightyear
# 8   Mazda, Mitsubishi, Nissan, Subaru, Suzuki, Toy...
# 1   Chery Automobile, Changan Automobile, CFMoto, ...

# %%
df_country.iloc[1]
# Out:
# country                                                                      China
# CarCompaniesNumOfCarCompanies                                                  124
# CarCompaniesMostPopularBrands    Chery Automobile, Changan Automobile, CFMoto, ...
# Name: 1, dtype: object

# %%
df_country['CarCompaniesMostPopularBrands'] = df_country["CarCompaniesMostPopularBrands"].str.split(',')
df_country
# Out:
#                  country  CarCompaniesNumOfCarCompanies  \
# 0                  India                              7
# 1                  China                            124
# 2          United States                            231
# 3               Pakistan                              1
# 4                Nigeria                              1
# 5                 Brazil                             10
# 6                 Russia                             24
# 7                 Mexico                              3
# 8                  Japan                             23
# 9                Vietnam                              1
# 10                  Iran                              2
# 11                Turkey                              3
# 12               Germany                            114
# 13              Thailand                              1
# 14        United Kingdom                            157
# 15                France                             72
# 16          South Africa                              3
# 17                 Italy                             61
# 18           South Korea                             10
# 19                 Spain                             20
# 20             Argentina                              7
# 21                Poland                              8
# 22                Canada                             17
# 23               Morocco                              1
# 24               Ukraine                              3
# 25            Uzbekistan                              1
# 26              Malaysia                              3
# 27             Australia                              9
# 28                Taiwan                              8
# 29             Sri Lanka                              1
# 30               Romania                              3
# 31           Netherlands                              9
# 32              Zimbabwe                              1
# 33               Belgium                              6
# 34                Sweden                             30
# 35        Czech Republic                              8
# 36              Portugal                              2
# 37               Hungary                              1
# 38  United Arab Emirates                              5
# 39                Israel                              3
# 40               Austria                              9
# 41           Switzerland                             12
# 42                Serbia                              3
# 43             Singapore                              1
# 44               Denmark                              2
# 45              Slovakia                              1
# 46               Finland                              2
# 47                Norway                              2
# 48           New Zealand                              1
# 49               Croatia                              1
# 50             Lithuania                              2
# 51              Slovenia                              3
# 52                Latvia                              6
# 53               Estonia                              2
# 54               Andorra                              1
# 55         Liechtenstein                              1
# 56                Monaco                              1
#
#                         CarCompaniesMostPopularBrands
# 0   [Royal Enfield,  Tata Motors,  TVS,  Force Mot...
# 1   [Chery Automobile,  Changan Automobile,  CFMot...
# 2   [Buick,  Cadillac,  Chevrolet,  Chrysler,  Dod...
# 3                                              [Adam]
# 4                                           [Innoson]
# 5                                [MP Lafer,  Troller]
# 6                   [AvtoVAZ,  Lada,  UAZ,  Moskvich]
# 7                        [Inferno,  Mastretta,  VUHL]
# 8   [Mazda,  Mitsubishi,  Nissan,  Subaru,  Suzuki...
# 9                                           [VinFast]
# 10                                     [IKCO,  Saipa]
# 11                           [Anadol,  Tekaydinlar, ]
# 12  [Audi,  BMW,  Mercedes-Benz,  Opel,  Porsche, ...
# 13                                        [Thai Rung]
# 14  [Aston Martin,  Bentley,  Jaguar,  Land Rover,...
# 15            [Bugatti,  Citroen,  Peugeot,  Renault]
# 16                           [Ranger,  CAV,  Barnard]
# 17  [Abarth,  Alfa Romeo,  Aprilia,  Ferrari,  Fia...
# 18           [Daewoo,  Genesis Motor,  Kia,  Hyundai]
# 19                                     [Cupra,  SEAT]
# 20                            [VOLT,  Hamelbot,  IKA]
# 21                                [Leopard,  Stoewer]
# 22                       [Monarch,  Ski Doo,  Can-Am]
# 23                                           [Laraki]
# 24                                              [ZAZ]
# 25                                            [Ravon]
# 26                        [Bufori,  Perodua,  Proton]
# 27                                           [Holden]
# 28                                 [Foxtron,  Luxgen]
# 29                                             [Vega]
# 30                                            [Dacia]
# 31                                        [Lightyear]
# 32                                            [Naran]
# 33                                           [Gillet]
# 34                          [Saab,  Polestar,  Volvo]
# 35                         [Skoda,  Jawa Motorcycles]
# 36                                [Irmaos Mota,  UMM]
# 37                                           [Cobera]
# 38                 [Devel,  Iconiq Motors,  W Motors]
# 39               [City Transformer,  Sabra,  Sussita]
# 40                                              [KTM]
# 41                               [Micro,  Monteverdi]
# 42                                   [Yugo,  Zastava]
# 43                                  [Vanda Electrics]
# 44                                 [Kleemann,  Zenvo]
# 45                                           [Rosero]
# 46                              [Solifer,  Toroidion]
# 47                                     [Kewet,  Vest]
# 48                                            [Hulme]
# 49                                            [Rimac]
# 50                                  [Altas,  Forveda]
# 51                           [Bravia-Mobil,  Shayton]
# 52                           [Baltijas Džips,  Dartz]
# 53                                      [Nobe,  TARK]
# 54                                    [TransAm Depot]
# 55                                     [NanoFlowcell]
# 56                                      [Monte Carlo]

# %%
df_country.iloc[0]
# Out:
# country                                  India
# CarCompaniesNumOfCarCompanies                7
# Car Make                         Royal Enfield
# Name: 0, dtype: object

# %%
df_country = df_country.explode('CarCompaniesMostPopularBrands').reset_index(drop=True)
df_country.rename(columns={"CarCompaniesMostPopularBrands": "Car Make"}, inplace=True)
df_country
# Out:
#            country  CarCompaniesNumOfCarCompanies          Car Make
# 0            India                              7     Royal Enfield
# 1            India                              7       Tata Motors
# 2            India                              7               TVS
# 3            India                              7      Force Motors
# 4            China                            124  Chery Automobile
# ..             ...                            ...               ...
# 146        Estonia                              2              Nobe
# 147        Estonia                              2              TARK
# 148        Andorra                              1     TransAm Depot
# 149  Liechtenstein                              1      NanoFlowcell
# 150         Monaco                              1       Monte Carlo
#
# [151 rows x 3 columns]

# %%
df_country[df_country["country"]=="China"]
# Out:
#    country  CarCompaniesNumOfCarCompanies                   Car Make
# 4    China                            124           Chery Automobile
# 5    China                            124         Changan Automobile
# 6    China                            124                     CFMoto
# 7    China                            124                   BYD Auto
# 8    China                            124                 Great Wall
# 9    China                            124                      Haval
# 10   China                            124                        LDV
# 11   China                            124                     Baojun
# 12   China                            124   Beijing Automobile Works
# 13   China                            124                       BJEV
# 14   China                            124               Farizon Auto
# 15   China                            124                  FAW Group
# 16   China                            124                 Hozon Auto

# %%
df_portfolio.sample(2)
# Out:
#           Car Make    Car Model  Year Engine Size (L) Horsepower  \
# 429  Mercedes-Benz     AMG C 63  2022               4        503
# 398       Maserati  GranTurismo  2022             4.7        454
#
#     Torque (lb-ft) 0-60 MPH Time (seconds) Price (in USD)
# 429            516                     3.8         70,000
# 398            384                     4.7        134,300

# %%
df_portfolio["key"] = df_portfolio["Car Make"].str.lower().str.replace(' ', '').str.replace('[^a-zA-Z0-9]', '')
df_country["key"] = df_country["Car Make"].str.lower().str.replace(' ', '').str.replace('[^a-zA-Z0-9]', '')

# %%
df_portfolio.sample(2)
# Out:
#           Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 236     Alfa Romeo        4C  2020             1.7        237            258
# 50   Mercedes-Benz   AMG C63  2021               4        503            516
#
#     0-60 MPH Time (seconds) Price (in USD)            key
# 236                     4.1         67,150      alfaromeo
# 50                      3.8         68,000  mercedes-benz

# %%
df_country.sample(2)
# Out:
#        country  CarCompaniesNumOfCarCompanies  Car Make      key
# 141  Lithuania                              2   Forveda  forveda
# 132    Denmark                              2     Zenvo    zenvo

# %%
df_merged = pd.merge(df_portfolio, df_country, on="key", how="left")
df_merged
# Out:
#        Car Make_x Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021  Electric Motor       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021  Electric Motor       1888           1696
#
#      0-60 MPH Time (seconds) Price (in USD)          key         country  \
# 0                          4        101,200      porsche         Germany
# 1                        2.8        274,390  lamborghini           Italy
# 2                          3        333,750      ferrari           Italy
# 3                        3.2        142,700         audi         Germany
# 4                        2.7        298,000      mclaren  United Kingdom
# ...                      ...            ...          ...             ...
# 1002                     2.5      3,000,000   koenigsegg             NaN
# 1003                       2      2,000,000        lotus  United Kingdom
# 1004                     2.7      1,000,000      mclaren  United Kingdom
# 1005                       3      2,600,000       pagani             NaN
# 1006                    1.85      2,400,000        rimac         Croatia
#
#       CarCompaniesNumOfCarCompanies    Car Make_y
# 0                             114.0       Porsche
# 1                              61.0   Lamborghini
# 2                              61.0       Ferrari
# 3                             114.0          Audi
# 4                             157.0       McLaren
# ...                             ...           ...
# 1002                            NaN           NaN
# 1003                          157.0         Lotus
# 1004                          157.0       McLaren
# 1005                            NaN           NaN
# 1006                            1.0         Rimac
#
# [1007 rows x 12 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Car Make_x                     1007 non-null   object
#  1   Car Model                      1007 non-null   object
#  2   Year                           1007 non-null   int64
#  3   Engine Size (L)                997 non-null    object
#  4   Horsepower                     1007 non-null   object
#  5   Torque (lb-ft)                 1004 non-null   object
#  6   0-60 MPH Time (seconds)        1007 non-null   object
#  7   Price (in USD)                 1007 non-null   object
#  8   key                            1007 non-null   object
#  9   country                        935 non-null    object
#  10  CarCompaniesNumOfCarCompanies  935 non-null    float64
#  11  Car Make_y                     935 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 94.5+ KB

# %%
df_merged["country"].value_counts()
# Out:
# country
# Germany                 276
# United Kingdom          215
# United States           168
# Italy                   162
# Japan                    72
# France                   23
# Croatia                  14
# United Arab Emirates      3
# Sweden                    1
# South Korea               1
# Name: count, dtype: int64

# %%
df_merged = df_merged[['Car Make_x',
                        'Car Model',
                        'Year',
                        'Price (in USD)',
                        'country']]

# %%
df_merged
# Out:
#        Car Make_x Car Model  Year Price (in USD)         country
# 0         Porsche       911  2022        101,200         Germany
# 1     Lamborghini   Huracan  2021        274,390           Italy
# 2         Ferrari   488 GTB  2022        333,750           Italy
# 3            Audi        R8  2022        142,700         Germany
# 4         McLaren      720S  2021        298,000  United Kingdom
# ...           ...       ...   ...            ...             ...
# 1002   Koenigsegg     Jesko  2022      3,000,000             NaN
# 1003        Lotus     Evija  2021      2,000,000  United Kingdom
# 1004      McLaren     Senna  2021      1,000,000  United Kingdom
# 1005       Pagani    Huayra  2021      2,600,000             NaN
# 1006        Rimac    Nevera  2021      2,400,000         Croatia
#
# [1007 rows x 5 columns]

# %%
df_merged["Price (in USD)"] = df_merged["Price (in USD)"].str.replace(",", "").astype(float)
# Out:
# /tmp/ipykernel_34734/4057544339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged["Price (in USD)"] = df_merged["Price (in USD)"].str.replace(",", "").astype(float)

# %%
df_merged
# Out:
#        Car Make_x Car Model  Year  Price (in USD)         country
# 0         Porsche       911  2022        101200.0         Germany
# 1     Lamborghini   Huracan  2021        274390.0           Italy
# 2         Ferrari   488 GTB  2022        333750.0           Italy
# 3            Audi        R8  2022        142700.0         Germany
# 4         McLaren      720S  2021        298000.0  United Kingdom
# ...           ...       ...   ...             ...             ...
# 1002   Koenigsegg     Jesko  2022       3000000.0             NaN
# 1003        Lotus     Evija  2021       2000000.0  United Kingdom
# 1004      McLaren     Senna  2021       1000000.0  United Kingdom
# 1005       Pagani    Huayra  2021       2600000.0             NaN
# 1006        Rimac    Nevera  2021       2400000.0         Croatia
#
# [1007 rows x 5 columns]

# %%
df_merged_filtered = df_merged[df_merged['Year'] >= 2020]
df_merged_filtered = df_merged_filtered[df_merged_filtered['Price (in USD)'] >= 100000]
df_merged_filtered = df_merged_filtered.dropna(subset=["country"], axis=0)

# %%
df_merged_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 555 entries, 0 to 1006
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Car Make_x      555 non-null    object
#  1   Car Model       555 non-null    object
#  2   Year            555 non-null    int64
#  3   Price (in USD)  555 non-null    float64
#  4   country         555 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 26.0+ KB

# %%
df_merged_filtered.sample(10)
# Out:
#        Car Make_x         Car Model  Year  Price (in USD)         country
# 497  Aston Martin  DBS Superleggera  2022        314500.0  United Kingdom
# 863       Bentley    Continental GT  2021        202500.0  United Kingdom
# 454       Ferrari         F8 Spider  2021        280000.0           Italy
# 874          Ford                GT  2022        500000.0   United States
# 994       McLaren                GT  2022        210000.0  United Kingdom
# 583          Ford                GT  2022        500000.0   United States
# 691          Audi        RS 6 Avant  2021        110000.0         Germany
# 366          Audi               RS7  2021        114000.0         Germany
# 315      Maserati       GranTurismo  2022        134300.0           Italy
# 466          Ford                GT  2022        500000.0   United States

# %%
# Se voce nao tiver um banco postgres

# docker run --name dnc-datasources -e POSTGRES_PASSWORD=dnc123 -e POSTGRES_USER:dnc -e POSTGRES_DB:datasource -p 5432:5432 -d postgres

# %%
from sqlalchemy import create_engine
import pandas as pd

username = 'postgres'
password = 'dnc123'
host = 'localhost'
port = 5432
database_name = 'postgres'

engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database_name}')

# %%
df_merged_filtered.to_sql('cars_by_countries_to_sales_campaign', con=engine, if_exists='replace', index=False)
# Out:
# 555
