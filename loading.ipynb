# %%
import pandas as pd

df = pd.read_csv("../input-data/WorldCups.csv", index_col=0)
df
# Out:
#            Country      Winner      Runners-Up        Third          Fourth  \
# Year
# 1930       Uruguay     Uruguay       Argentina          USA      Yugoslavia
# 1934         Italy       Italy  Czechoslovakia      Germany         Austria
# 1938        France       Italy         Hungary       Brazil          Sweden
# 1950        Brazil     Uruguay          Brazil       Sweden           Spain
# 1954   Switzerland  Germany FR         Hungary      Austria         Uruguay
# 1958        Sweden      Brazil          Sweden       France      Germany FR
# 1962         Chile      Brazil  Czechoslovakia        Chile      Yugoslavia
# 1966       England     England      Germany FR     Portugal    Soviet Union
# 1970        Mexico      Brazil           Italy   Germany FR         Uruguay
# 1974       Germany  Germany FR     Netherlands       Poland          Brazil
# 1978     Argentina   Argentina     Netherlands       Brazil           Italy
# ...

# %%
import boto3
from io import BytesIO

# %%
# !pip install pyarrow
# Out:
# ...
#   Using cached pyarrow-16.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
# ...

# %%
buffer = BytesIO()
df.to_parquet(buffer, engine="pyarrow")

df
# Out:
#            Country      Winner      Runners-Up        Third          Fourth  \
# Year
# 1930       Uruguay     Uruguay       Argentina          USA      Yugoslavia
# 1934         Italy       Italy  Czechoslovakia      Germany         Austria
# 1938        France       Italy         Hungary       Brazil          Sweden
# 1950        Brazil     Uruguay          Brazil       Sweden           Spain
# 1954   Switzerland  Germany FR         Hungary      Austria         Uruguay
# 1958        Sweden      Brazil          Sweden       France      Germany FR
# 1962         Chile      Brazil  Czechoslovakia        Chile      Yugoslavia
# 1966       England     England      Germany FR     Portugal    Soviet Union
# 1970        Mexico      Brazil           Italy   Germany FR         Uruguay
# 1974       Germany  Germany FR     Netherlands       Poland          Brazil
# 1978     Argentina   Argentina     Netherlands       Brazil           Italy
# ...

# %%
s3_client = boto3.client('s3')

bucket_name = "dnc-lucas-tutorial-class"
file_key = "loading/full_data.parquet"

# %%
s3_client.upload_fileobj(buffer, bucket_name, file_key)

# %%
list(df.columns)
# Out:
# ['Country',
#  'Winner',
#  'Runners-Up',
#  'Third',
#  'Fourth',
#  'GoalsScored',
#  'QualifiedTeams',
#  'MatchesPlayed',
#  'Attendance']

# %%
df.index
# Out:
# Index([1930, 1934, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982,
#        1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014],
#       dtype='int64', name='Year')

# %%
df = df.reset_index()
df
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 1.7+ KB

# %%
df["Year"] = df["Year"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     object
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     object
# dtypes: int64(3), object(7)
# memory usage: 1.7+ KB

# %%
import pyarrow
import pyarrow.parquet as pq
import s3fs

pq.write_to_dataset(
    pyarrow.Table.from_pandas(df),
    'dnc-lucas-tutorial-class/loading',
    filesystem=s3fs.S3FileSystem(),
    partition_cols=["Year"]
)

# %%
import pandas as pd

df = pd.read_csv("../input-data/spotify/track.csv", index_col=0)
df
# Out:
#                         track_popularity
# track_id
# 02MBhqgR7WeeI4ZfB6Lo0i                 0
# 5j4M4gLYuUy9PVw0vsXWyq                 0
# 46EucLPJpx0QM3SCjzzdP0                 0
# 4nK2LvW3osgDT89S38Mcg6                 0
# 1Pq37WIQZDG7yNFnY5IbqG                 0
# ...                                  ...
# 4rXLjWdF2ZZpXCVTfWcshS                93
# 7MXVkk9YMctZqd1Srtv4MB                94
# 6uIIdjYTxxpWOyWuVXrKQO                95
# 4MjDJD8cW7iVeWInc2Bdyj                96
# 7iQXYTyuG13aoeHxGG28Nh                97
#
# [438938 rows x 1 columns]

# %%
import pyarrow
import pyarrow.parquet as pq
import s3fs

pq.write_to_dataset(
    pyarrow.Table.from_pandas(df),
    'dnc-project-data-eng/staging',
    filesystem=s3fs.S3FileSystem()
)
